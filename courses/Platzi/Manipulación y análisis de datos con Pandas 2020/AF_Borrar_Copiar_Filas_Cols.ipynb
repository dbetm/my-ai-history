# %%
import numpy as np
import pandas as pd

# %%
# dataset link: https://data.nasa.gov/Space-Science/Meteorite-Landings/gh4g-9sfh
dataset_path = "/home/david/ML_DL/datasets/NASA_Meteorite_Landings/Meteorite_Landings.csv"

# %%
data = pd.read_csv(dataset_path)

# %%
data.head(2)
# Out:
#      name  id nametype recclass  mass (g)  fall                    year  \
# 0  Aachen   1    Valid       L5      21.0  Fell  01/01/1880 12:00:00 AM
# 1  Aarhus   2    Valid       H6     720.0  Fell  01/01/1951 12:00:00 AM
#
#      reclat   reclong           GeoLocation
# 0  50.77500   6.08333     (50.775, 6.08333)
# 1  56.18333  10.23333  (56.18333, 10.23333)

# %%
# borrar una columna
data.drop(["GeoLocation"], axis=1, inplace=True)

# %%
# borrar ciertas filas
data.drop(index=[0, 2, 4, 6]).head(10)
# Out:
#                 name   id nametype      recclass  mass (g)  fall  \
# 1             Aarhus    2    Valid            H6     720.0  Fell
# 3           Acapulco   10    Valid   Acapulcoite    1914.0  Fell
# 5           Adhi Kot  379    Valid           EH4    4239.0  Fell
# 7               Agen  392    Valid            H5   30000.0  Fell
# 8             Aguada  398    Valid            L6    1620.0  Fell
# 9      Aguila Blanca  417    Valid             L    1440.0  Fell
# 10  Aioun el Atrouss  423    Valid  Diogenite-pm    1000.0  Fell
# 11               Aïr  424    Valid            L6   24000.0  Fell
# 12   Aire-sur-la-Lys  425    Valid       Unknown       NaN  Fell
# 13             Akaba  426    Valid            L6     779.0  Fell
#
#                       year    reclat   reclong
# 1   01/01/1951 12:00:00 AM  56.18333  10.23333
# 3   01/01/1976 12:00:00 AM  16.88333 -99.90000
# 5   01/01/1919 12:00:00 AM  32.10000  71.80000
# 7   01/01/1814 12:00:00 AM  44.21667   0.61667
# ...

# %%
# copiar un dataframe, es ideal para hacer ediciones del df
new_data = data.copy(deep=True)
